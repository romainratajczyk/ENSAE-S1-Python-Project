# %% [markdown]
# Version Reproductible & Propre du précédent code "fusions_data".
#
# à faire: réorganiser le Git:
#
# beau readme
# librairies à installer
# ce que le projet nous a appris
#
# data/
#     raw_Insee/
#     raw_elections/
#     merged/
#
# notebooks/
#     data_preparation (python pandas)
#     analyse_modelisation (regression statsmodel)
#     vizualisation (geopandas)
#
# fct/
#     si des fonctions python a appeller
#
#
#
# STANDARDISER LES VARIABLES
# vérifier les path de chaque code (j'ai renommé certains path pour y voir plus clair)

# %% [markdown]
# LE FICHIER DE SORTIE EST DISPONIBLE SUR LE GIT. MAIS CE CODE LE GENERE SI BESOIN (pour vérifier la réplicabilité par exemple si vous le souhaitez!)

# %%
import pandas as pd
import numpy as np
import os

# Récupère le dossier où se trouve ce notebook
NOTEBOOK_DIR = os.getcwd()

# '..' remonte d'un cran pour accéder au dossier data, puis sous dossiers Insee et elections
RAW_INSEE_DIR = os.path.join(NOTEBOOK_DIR, '..', 'data', 'raw_Insee')
RAW_ELEC_DIR = os.path.join(NOTEBOOK_DIR, '..', 'data', 'raw_elections')
# On remplace 'processed' par 'merged'
MERGED_DATA_DIR = os.path.join(NOTEBOOK_DIR, '..', 'data', 'merged')

# On vérifie que le dossier de sortie existe, sinon on le crée
os.makedirs(MERGED_DATA_DIR, exist_ok=True)

print(f"OK Source INSEE : {RAW_INSEE_DIR}")
print(f"OK Source Élections : {RAW_ELEC_DIR}")
print(f"OK Destination : {MERGED_DATA_DIR}")
# Out:
# OK Source INSEE : /Users/romain/Desktop/Projets DS/Python-project/notebooks/../data/raw_Insee
# OK Source Élections : /Users/romain/Desktop/Projets DS/Python-project/notebooks/../data/raw_elections
# OK Destination : /Users/romain/Desktop/Projets DS/Python-project/notebooks/../data/merged

# %%
# Dictionnaire des fichiers raw INSEE
FILES_INSEE = {
    'pop_2020': 'population_2020.CSV',
    'pop_2014': 'population_2014.xls',
    'diplo_2020': 'diplome_2020.CSV',
    'diplo_2014': 'diplome_2014.xls',
    'rev_2019': 'revenu_2019.csv',
    'rev_2013': 'revenu_2013.xls'
}



# POPULATION & CADRES
# rq: en-têtes pour excel Insee (header=5)
df_pop_2020 = pd.read_csv(os.path.join(RAW_INSEE_DIR, FILES_INSEE['pop_2020']), sep=';', dtype={'COM': str})
df_pop_2014 = pd.read_excel(os.path.join(RAW_INSEE_DIR, FILES_INSEE['pop_2014']), header=5, dtype={'COM': str})

# DIPLÔMES
df_diplo_2020 = pd.read_csv(os.path.join(RAW_INSEE_DIR, FILES_INSEE['diplo_2020']), sep=';', header=0, dtype={'COM': str})
df_diplo_2014 = pd.read_excel(os.path.join(RAW_INSEE_DIR, FILES_INSEE['diplo_2014']), header=5, dtype={'CODGEO': str})
# REVENUS
df_rev_2019 = pd.read_csv(os.path.join(RAW_INSEE_DIR, FILES_INSEE['rev_2019']), sep=';', dtype={'CODGEO': str})
df_rev_2013 = pd.read_excel(os.path.join(RAW_INSEE_DIR, FILES_INSEE['rev_2013']), header=5, dtype={'CODGEO': str})

print("Données chargées.")
# Out:
# /var/folders/47/r5kv9z4j6kg1sk0dvr2l5ydh0000gn/T/ipykernel_43728/322832310.py:15: DtypeWarning: Columns (0,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_pop_2020 = pd.read_csv(os.path.join(RAW_INSEE_DIR, FILES_INSEE['pop_2020']), sep=';', dtype={'COM': str})
# /var/folders/47/r5kv9z4j6kg1sk0dvr2l5ydh0000gn/T/ipykernel_43728/322832310.py:19: DtypeWarning: Columns (0,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_diplo_2020 = pd.read_csv(os.path.join(RAW_INSEE_DIR, FILES_INSEE['diplo_2020']), sep=';', header=0, dtype={'COM': str})
# Données chargées.

# %% [markdown]
# Cellule de visualisation (réservée aux .head() )

# %%
df_pop_2020.head(20)
# Out:
#         IRIS    COM TYP_IRIS LAB_IRIS      P20_POP  P20_POP0002  P20_POP0305  \
# 0   10010000  01001        Z        5   806.000000    31.484313    26.911746
# 1   10020000  01002        Z        5   262.000000     5.988437    12.166343
# 2   10040101  01004        H        1  1805.376610    80.347443    44.940185
# 3   10040102  01004        H        1  3633.137558   151.531803   133.872557
# 4   10040201  01004        H        1  4097.728721   165.340974   169.880658
# 5   10040202  01004        H        1  4751.757111   153.751141   186.444716
# 6   10050000  01005        Z        5  1782.000000    63.000000    69.000000
# 7   10060000  01006        Z        5   113.000000     2.973684     2.973684
# 8   10070000  01007        Z        5  2827.000000   116.129773   111.845504
# 9   10080000  01008        Z        5   768.000000    21.161093    28.094502
# 10  10090000  01009        Z        5   324.000000     4.810169     7.674257
# 11  10100000  01010        Z        5  1101.000000    40.608398    47.787948
# 12  10110000  01011        Z        5   368.000000    14.064795    14.203463
# 13  10120000  01012        Z        5   327.000000     9.068663    13.078886
# 14  10130000  01013        Z        5   143.000000     6.951389     5.958333
# 15  10140000  01014        Z        5  3336.000000    83.744084   100.274328
# 16  10150000  01015        Z        5   663.000000    16.304612    16.219313
# 17  10160000  01016        Z        5   458.000000    10.000000    20.000000
# 18  10170000  01017        Z        5   445.000000    14.821074    10.326138
# 19  10190000  01019        Z        5    26.000000     0.000000     1.000000
#
#     P20_POP0610  P20_POP1117  P20_POP1824  ...  C20_F15P_CS4  C20_F15P_CS5  \
# 0     53.754190    77.438835    28.293681  ...     46.590055     79.695680
# 1     19.185203    34.218154    11.595410  ...     24.305648     14.371604
# 2     98.034462   132.206137   350.595992  ...    102.223408    239.751222
# 3    207.372432   257.669740   376.985965  ...    180.432551    402.975969
# 4    243.321681   360.778807   327.817455  ...    254.897967    396.638516
# 5    319.865260   461.632363   294.816387  ...    366.443598    429.109321
# 6    125.000000   157.000000   101.000000  ...    115.000000    250.000000
# 7      3.964912     1.982456     5.947368  ...      0.000000     14.868421
# 8    221.523484   280.653166   142.292168  ...    232.838955    318.671552
# 9     48.160740    69.216441    52.423992  ...     70.547686     86.746483
# 10    18.952590    30.850680    17.597934  ...     45.021826     39.881448
# 11    99.370044   103.806966    46.030514  ...     38.972938    148.588059
# 12    32.656142    35.894328    10.702579  ...     24.033565     19.650810
# 13    20.164919    34.250117    11.036403  ...     15.049648     40.177613
# 14     8.937500    10.923611     6.951389  ...      4.965278     19.861111
# 15   243.894297   315.604086   193.254184  ...    134.407077    251.202590
# 16    36.444485    57.815119    39.711074  ...     56.433983     61.403667
# 17    35.000000    57.000000    14.000000  ...     45.000000     45.000000
# 18    36.371641    41.648680    22.502701  ...     10.222866     60.729751
# 19     2.000000     0.000000     2.000000  ...      0.000000      0.000000
#
#     C20_F15P_CS6  C20_F15P_CS7  C20_F15P_CS8   P20_POP_FR  P20_POP_ETR  \
# 0      28.079284     82.546801     28.071601   796.562592     9.437408
# 1       4.493918     22.196847      4.493918   260.981319     1.018681
# 2      51.887787    169.925225    186.025416  1550.387323   254.989286
# 3     154.584388    420.664788    310.793231  3170.910863   462.226695
# 4     170.174486    529.191909    323.199708  3690.082310   407.646411
# 5     134.712896    537.641133    372.659811  4554.685863   197.071248
# 6      20.000000    185.000000     80.000000  1749.000000    33.000000
# 7       4.956140      9.912281      0.000000   109.035088     3.964912
# 8      70.638058    225.103608    176.106539  2770.835399    56.164601
# 9      25.638031     67.217211     25.502495   749.805263    18.194737
# 10      0.000000     41.575061     14.694386   314.231492     9.768508
# 11     50.463338     94.019520     62.473681  1068.265548    32.734452
# 12      0.000000     51.158724     14.389763   361.043868     6.956132
# 13      5.016535     54.973594     10.009236   321.989422     5.010578
# 14      4.965278      4.965278      9.930556   143.000000     0.000000
# 15    132.067212    518.364359    276.359923  2884.309716   451.690284
# 16     15.243744     98.385400     30.677780   652.688687    10.311313
# 17     10.000000     65.000000      5.000000   447.000000    11.000000
# 18      4.931375     68.107748     53.723020   428.420022    16.579978
# 19      5.000000     10.000000      0.000000    24.000000     2.000000
#
#     P20_POP_IMM     P20_PMEN  P20_PHORMEN
# 0     17.783541   806.000000     0.000000
# 1      2.761700   262.000000     0.000000
# 2    213.675617  1442.383120   362.993490
# 3    575.389845  3633.137558     0.000000
# 4    424.023175  4009.730299    87.998422
# 5    382.470417  4701.758008    49.999103
# 6     73.000000  1782.000000     0.000000
# 7      3.964912   113.000000     0.000000
# 8    102.013341  2817.000090     9.999910
# 9     25.330477   768.000000     0.000000
# 10    13.886450   324.000000     0.000000
# 11    58.661526  1101.000000     0.000000
# 12     7.939680   368.000000     0.000000
# 13     8.011565   325.002919     1.997081
# 14     1.986111   143.000000     0.000000
# 15   768.316230  3292.996697    43.003303
# 16    20.565932   663.000000     0.000000
# 17    15.000000   458.000000     0.000000
# 18    22.479928   445.000000     0.000000
# 19     3.000000    26.000000     0.000000
#
# [20 rows x 76 columns]

# %%
# Transformation des données socio-démographiques

# Population & cadres
# 2020
pop20 = df_pop_2020[['COM', 'P20_POP', 'C20_POP15P_CS3']].copy()
pop20.columns = ['COM', 'pop_2020', 'cadres_nb_2020']

# 2014 (Attention INSEE change parfois COM en CODGEO, ici on assure)
pop14 = df_pop_2014[['COM', 'P14_POP', 'C14_POP15P_CS3']].copy()
pop14.columns = ['COM', 'pop_2014', 'cadres_nb_2014']

# Diplomes

# 2020 : Il faut sommer les colonnes (Sup court + Sup long...) pour se rabaisser à la definition de 2014 qui est vulgairement agrégée
df_diplo_2020['sup_nb_2020'] = (
    df_diplo_2020['P20_NSCOL15P_SUP2'] + 
    df_diplo_2020['P20_NSCOL15P_SUP34'] + 
    df_diplo_2020['P20_NSCOL15P_SUP5']
)
dip20 = df_diplo_2020[['COM', 'sup_nb_2020']].copy()

# 2014
dip14 = df_diplo_2014[['CODGEO', 'P14_NSCOL15P_SUP']].copy()
dip14.columns = ['COM', 'sup_nb_2014']

# Revenus
rev19 = df_rev_2019[['CODGEO', 'MED19']].rename(columns={'CODGEO': 'COM', 'MED19': 'med_2019'})
rev13 = df_rev_2013[['CODGEO', 'MED13']].rename(columns={'CODGEO': 'COM', 'MED13': 'med_2013'})

# Fusion globale des données socio-démographiques

# On part de la population 2020 comme base
df_socio = pop20.merge(pop14, on='COM', how='inner')
df_socio = df_socio.merge(dip20, on='COM', how='left')
df_socio = df_socio.merge(dip14, on='COM', how='left')
df_socio = df_socio.merge(rev19, on='COM', how='left')
df_socio = df_socio.merge(rev13, on='COM', how='left')

# problème possible log(0): on résout, ainsi que secret statistique et NaN pour les revenus

# Transforme les 's' (secret statistique) en NaN
df_socio['med_2013'] = pd.to_numeric(df_socio['med_2013'], errors='coerce')
df_socio['med_2019'] = pd.to_numeric(df_socio['med_2019'], errors='coerce')

#  Supprime les lignes avec un revenu ou une population de 0
df_socio = df_socio[(df_socio['med_2013'] > 0) & (df_socio['med_2019'] > 0) & (df_socio['pop_2014'] > 0) & (df_socio['pop_2020'] > 0)]


# Calcul des variables Delta

# Croissance Pop (Log-diff)
df_socio['croissance_pop'] = np.log(df_socio['pop_2020']) - np.log(df_socio['pop_2014'])

#  Delta Diplômés (Variation en  %)
df_socio['pct_sup_2020'] = df_socio['sup_nb_2020'] / df_socio['pop_2020']
df_socio['pct_sup_2014'] = df_socio['sup_nb_2014'] / df_socio['pop_2014']
df_socio['delta_pct_diplome'] = df_socio['pct_sup_2020'] - df_socio['pct_sup_2014']

# Delta Cadres (Variation  %)
df_socio['pct_cadres_2020'] = df_socio['cadres_nb_2020'] / df_socio['pop_2020']
df_socio['pct_cadres_2014'] = df_socio['cadres_nb_2014'] / df_socio['pop_2014']
df_socio['delta_pct_cadres'] = df_socio['pct_cadres_2020'] - df_socio['pct_cadres_2014']

# Richesse initiale (Log)
df_socio['log_med_13'] = np.log(df_socio['med_2013'])

print(f"Base socio-démographique prête : {df_socio.shape[0]} communes.")
# Out:
# /opt/anaconda3/envs/datasci/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Base socio-démographique prête : 26623586 communes.

# %% [markdown]
# A FAIRE: resoudre le probleme de log(0)

# %%
# CHARGEMENT ELECTIONS


# VERIFIER bien CODE NUANCE et pas NUANCE LISTE
df_elec_14 = pd.read_csv(os.path.join(RAW_ELEC_DIR, 'elec_2014.csv'), dtype={'Code commune': str})
df_elec_20 = pd.read_csv(os.path.join(RAW_ELEC_DIR, 'elec_2020.csv'), dtype={'Code commune': str})
df_elec_20 = df_elec_20.rename(columns={'Nuance Liste': 'Code Nuance'})

# Renommer si nécessaire (verifier Code Nuance)
df_elec_14 = df_elec_14.rename(columns={'Code commune': 'COM'})
df_elec_20 = df_elec_20.rename(columns={'Code commune': 'COM'})

# DÉFINITION DU BLOC GAUCHE + ÉCOLOS 

BLOC_GAUCHE = [
    'LVECE', 'LVEC', 'LECO',         # Écolos
    'LUG', 'LDVG', 'LSOC', 'LFI',    # Gauche diverse, PS, LFI
    'LGEN', 'LCOM', 'LRDG', 'LGRA', 'LPG' # PCF, Front de gauche, etc.
]

# Idée: mettr à 0 le score si pas de liste de gauche. C'est fait plus bas lors du merge

def calcul_score_bloc(df_elec, nuances_bloc, annee):
    """Calcule la somme des voix du bloc pour chaque commune."""
    # Filtrer les nuances du bloc (gauche dans notre cas)
    mask = df_elec['Code Nuance'].isin(nuances_bloc)
    df_filtered = df_elec[mask].copy()
    
    # Sommer par commune (cas où il y a >=2 listes de gauche)
    scores = df_filtered.groupby('COM')['% Voix/Exp'].sum().reset_index()
    scores.rename(columns={'% Voix/Exp': f'score_gauche_{annee}'}, inplace=True)
    return scores

# appel a la fction, calcul des scores
score_14 = calcul_score_bloc(df_elec_14, BLOC_GAUCHE, '2014')
score_20 = calcul_score_bloc(df_elec_20, BLOC_GAUCHE, '2020')

print("Scores calculés.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/datasci/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Code Nuance'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 35
#      33 # appel a la fction, calcul des scores
#      34 score_14 = calcul_score_bloc(df_elec_14, BLOC_GAUCHE, '2014')
# ---> 35 score_20 = calcul_score_bloc(df_elec_20, BLOC_GAUCHE, '2020')
#      37 print("Scores calculés.")
#
# Cell In[5], line 25, in calcul_score_bloc(df_elec, nuances_bloc, annee)
#      23 """Calcule la somme des voix du bloc pour chaque commune."""
#      24 # Filtrer les nuances du bloc (gauche dans notre cas)
# ---> 25 mask = df_elec['Code Nuance'].isin(nuances_bloc)
#      26 df_filtered = df_elec[mask].copy()
#      28 # Sommer par commune (cas où il y a >=2 listes de gauche)
#
# File /opt/anaconda3/envs/datasci/lib/python3.11/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File /opt/anaconda3/envs/datasci/lib/python3.11/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Code Nuance'

# %%
# On part de la base socio-demo (qui contient toutes les communes)
df_final = df_socio.copy()

# On colle les scores 2014
df_final = df_final.merge(score_14, on='COM', how='left')

# On colle les scores 2020
df_final = df_final.merge(score_20, on='COM', how='left')

# CRUCIAL pour la regression: Remplacer les NaN par 0
# Si pas de correspondance, ça veut dire 0 voix pour la gauche
df_final['score_gauche_2014'] = df_final['score_gauche_2014'].fillna(0)
df_final['score_gauche_2020'] = df_final['score_gauche_2020'].fillna(0)

# Calcul du DELTA SCORE (Variable Y)
df_final['delta_score_gauche'] = df_final['score_gauche_2020'] - df_final['score_gauche_2014']

# Sélection des colonnes (pour R par exemple, analyse faite en R temporairement)
cols_export = [
    'COM',
    'score_gauche_2014',  
    'score_gauche_2020', 
    'delta_score_gauche',
    'pop_2014',
    'pop_2020', 
    'croissance_pop', 
    'pct_sup_2014',
    'pct_sup_2020',
    'delta_pct_diplome', 
    'pct_cadres_2014',
    'pct_cadres_2020',  
    'delta_pct_cadres', 
    'med_2013',
    'med_2019',   
    'log_med_13',
    'log_med_19' 

]

# On retire les lignes avec des NaN dans les variables explicatives (Socio-demo manquantes)
# faire analyse des données perdues ? 
df_export = df_final[cols_export].dropna()

print(f"Base finale prête : {len(df_export)} communes.")
print(df_export.head())

# %% [markdown]
# Cellule de visualisation (réservée aux .head() ) pour vérifier la cohérence

# %%
df_export.head()

# %%
output_filename = 'data_regression.csv'
output_path = os.path.join(MERGED_DATA_DIR, output_filename)

df_export.to_csv(
    output_path, 
    index=False, 
    sep=',', 
    encoding='utf-8', 
    na_rep='NA' # Pour compatibilité R
)

print(f"Fichier exporté avec succès : {output_path}")
